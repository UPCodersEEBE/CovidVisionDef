# %%
Diccionari = {
"Cherokee":[67,382]
,"Clay":[102,392]
,"Macon":[130,380]
,"Jackson":[159,366]
,"Transylvania":[189,378]
,"Henderson":[215,365]
,"Polk":[242,369]
,"Rutherford":[268,358]
,"Cleveland":[301,366]
,"Gaston":[331,368]

,"Mecklenburg":[362,377]
,"Union":[386,404]
,"Cabarrus":[386,358]
,"Anson":[427,402]
,"Stanly":[414,364]
,"Montgomery":[445,366]
,"Richmond":[461,401]
,"Moore":[484,365]
,"Scotland":[485,418]
,"Hoke":[504,396]
,"Cumberland":[541,391]
,"Robeson":[515,439]
,"Bladen":[563,440]
,"Columbus":[553,479]

,"New Hanover":[629,479]
,"Pender":[625,448]
,"Sampson":[583,397]
,"Duplin":[622,401]
,"Graham":[92,358]
,"Swain":[127,344]
,"Haywood":[171,339]
,"Madison":[197,305]
,"Buncombe":[211,332]
,"Yancey":[234,302]
,"Mitchell":[241,281]
,"McDowell":[253,326]
,"Burke":[283,320]
,"Avery":[266,280]
,"Caldwell":[297,296]
,"Catawba":[325,327]
,"Alexander":[331,300]
,"Iredell":[357,311]
,"Rowan":[384,329]
,"Davie":[385,298]
,"Davidson":[416,311]
,"Randolph":[450,322]
,"Chatham":[495,322]
,"Lee":[511,348]
,"Harnett":[535,360]
,"Wake":[551,315]
,"Johnston":[582,340]
,"Wayne":[613,356]
,"Onslow":[669,426]
,"Jones":[668,388]
,"Carteret":[746,409]
,"Craven":[689,373]
,"Lenoir":[645,373]

,"Pamlico":[721,381]

,"Ashe":[301,244]
,"Wilkes":[333,266]

,"Yadkin":[375,274]
,"Surry":[372,244]

,"Stokes":[413,250]
,"Guilford":[453,283]
,"Rockingham":[453,247]
,"Caswell":[491,246]
,"Alamance":[488,288]
,"Orange":[513,282]
,"Durham":[535,287]
,"Person":[525,248]
,"Granville":[551,256]
,"Vance":[575,248]
,"Franklin":[587,278]
,"Warren":[601,246]
,"Nash":[613,292]
,"Wilson":[621,318]
,"Halifax":[633,256]
,"Edgecombe":[647,298]
,"Pitt":[667,327]
,"Beaufort":[714,337]
,"Hyde":[770,338]
,"Dare":[803,304]

,"Martin":[691,308]
,"Northampton":[667,240]
,"Hertford":[696,244]
,"Bertie":[701,274]
,"Washington":[741,300]
,"Chowan":[731,271]
,"Gates":[724,233]
,"Perquimans":[746,256]
,"Pasquotank":[760,247]
,"Camden":[758,230]
,"Currituck":[788,239]}

# %%
import pandas as pd  
import time
dades = pd.read_csv('time_series_covid19_deaths_US.csv')  
                                   
dades = pd.DataFrame(dades)  

dades
# Out:
#            UID iso2 iso3  code3     FIPS      Admin2 Province_State  \
# 0     84001001   US  USA    840   1001.0     Autauga        Alabama
# 1     84001003   US  USA    840   1003.0     Baldwin        Alabama
# 2     84001005   US  USA    840   1005.0     Barbour        Alabama
# 3     84001007   US  USA    840   1007.0        Bibb        Alabama
# 4     84001009   US  USA    840   1009.0      Blount        Alabama
# ...        ...  ...  ...    ...      ...         ...            ...
# 3335  84056039   US  USA    840  56039.0       Teton        Wyoming
# 3336  84056041   US  USA    840  56041.0       Uinta        Wyoming
# 3337  84090056   US  USA    840  90056.0  Unassigned        Wyoming
# 3338  84056043   US  USA    840  56043.0    Washakie        Wyoming
# 3339  84056045   US  USA    840  56045.0      Weston        Wyoming
#
#      Country_Region        Lat       Long_  ... 10/7/20  10/8/20  10/9/20  \
# 0                US  32.539527  -86.644082  ...      27       28       28
# ...

# %%
dades2=dades[dades["Province_State"] == "North Carolina"]

dades2
# Out:
#            UID iso2 iso3  code3     FIPS     Admin2  Province_State  \
# 1964  84037001   US  USA    840  37001.0   Alamance  North Carolina
# 1965  84037003   US  USA    840  37003.0  Alexander  North Carolina
# 1966  84037005   US  USA    840  37005.0  Alleghany  North Carolina
# 1967  84037007   US  USA    840  37007.0      Anson  North Carolina
# 1968  84037009   US  USA    840  37009.0       Ashe  North Carolina
# ...        ...  ...  ...    ...      ...        ...             ...
# 2061  84037191   US  USA    840  37191.0      Wayne  North Carolina
# 2062  84037193   US  USA    840  37193.0     Wilkes  North Carolina
# 2063  84037195   US  USA    840  37195.0     Wilson  North Carolina
# 2064  84037197   US  USA    840  37197.0     Yadkin  North Carolina
# 2065  84037199   US  USA    840  37199.0     Yancey  North Carolina
#
#      Country_Region        Lat      Long_  ... 10/7/20  10/8/20  10/9/20  \
# 1964             US  36.043470 -79.399761  ...      59       59       59
# ...

# %%
dades2 = dades2.drop(columns = ["UID", "iso2", "iso3", "code3", "FIPS", "Country_Region", "Population", "Combined_Key"])
dades2
# Out:
#          Admin2  Province_State        Lat      Long_  1/22/20  1/23/20  \
# 1964   Alamance  North Carolina  36.043470 -79.399761        0        0
# 1965  Alexander  North Carolina  35.922380 -81.177519        0        0
# 1966  Alleghany  North Carolina  36.493609 -81.128570        0        0
# 1967      Anson  North Carolina  34.974032 -80.099533        0        0
# 1968       Ashe  North Carolina  36.432962 -81.498627        0        0
# ...         ...             ...        ...        ...      ...      ...
# 2061      Wayne  North Carolina  35.364381 -78.000273        0        0
# 2062     Wilkes  North Carolina  36.208413 -81.162329        0        0
# 2063     Wilson  North Carolina  35.706255 -77.917978        0        0
# 2064     Yadkin  North Carolina  36.162226 -80.662394        0        0
# 2065     Yancey  North Carolina  35.900792 -82.312372        0        0
#
#       1/24/20  1/25/20  1/26/20  1/27/20  ...  10/7/20  10/8/20  10/9/20  \
# ...

# %%
def change_coords(dades2, dic_coords):
    dades3=dades2.copy(deep=True)
    dades3["County"]=dades3["Admin2"]
    dades3.set_index("Admin2",drop=True, inplace=True)
    
    for key in Diccionari.keys():
        dades3.loc[key,"Lat"]=Diccionari[key][0]
        dades3.loc[key,"Long_"]=Diccionari[key][1]
    
    dades2=dades3
    return dades2
df3=change_coords(dades2, Diccionari)
df3
# Out:
#            Province_State         Lat      Long_  1/22/20  1/23/20  1/24/20  \
# Admin2
# Alamance   North Carolina  488.000000  288.00000        0        0        0
# Alexander  North Carolina  331.000000  300.00000        0        0        0
# Alleghany  North Carolina   36.493609  -81.12857        0        0        0
# Anson      North Carolina  427.000000  402.00000        0        0        0
# Ashe       North Carolina  301.000000  244.00000        0        0        0
# ...                   ...         ...        ...      ...      ...      ...
# Wayne      North Carolina  613.000000  356.00000        0        0        0
# Wilkes     North Carolina  333.000000  266.00000        0        0        0
# Wilson     North Carolina  621.000000  318.00000        0        0        0
# Yadkin     North Carolina  375.000000  274.00000        0        0        0
# Yancey     North Carolina  234.000000  302.00000        0        0        0
#
# ...

# %%
dia = "10/10/20"
estat = "Yadkin"

coordenada_1 = int(df3.at[estat, "Lat"])
coordenada_2 = int(df3.at[estat, "Long_"])
radi = df3.at["Yadkin", "10/10/20"]

def printear():
    for i in range(50):
        
        for i in o:
            estat = i 
            dia = "10/16/20"

            coordenada_1 = int(df3.at[estat, "Lat"])
            coordenada_2 = int(df3.at[estat, "Long_"])
            radi = int(0.1*df3.at[estat, dia])


            pygame.draw.circle(screen,(155,0,0),(coordenada_1, coordenada_2), radi)

# %%
f = list(df3.columns)
u = f.index("County")
t = df3.iloc[:,u]
o = list(t)
o
# Out:
# ['Alamance',
#  'Alexander',
#  'Alleghany',
#  'Anson',
#  'Ashe',
#  'Avery',
#  'Beaufort',
#  'Bertie',
#  'Bladen',
#  'Brunswick',
#  'Buncombe',
#  'Burke',
#  'Cabarrus',
#  'Caldwell',
#  'Camden',
#  'Carteret',
#  'Caswell',
#  'Catawba',
#  'Chatham',
#  'Cherokee',
#  'Chowan',
#  'Clay',
#  'Cleveland',
#  'Columbus',
#  'Craven',
#  'Cumberland',
#  'Currituck',
#  'Dare',
#  'Davidson',
#  'Davie',
#  'Duplin',
#  'Durham',
#  'Edgecombe',
#  'Forsyth',
#  'Franklin',
#  'Gaston',
#  'Gates',
#  'Graham',
#  'Granville',
#  'Greene',
#  'Guilford',
#  'Halifax',
#  'Harnett',
#  'Haywood',
#  'Henderson',
#  'Hertford',
#  'Hoke',
#  'Hyde',
#  'Iredell',
#  'Jackson',
#  'Johnston',
#  'Jones',
#  'Lee',
#  'Lenoir',
#  'Lincoln',
#  'Macon',
#  'Madison',
#  'Martin',
#  'McDowell',
#  'Mecklenburg',
#  'Mitchell',
#  'Montgomery',
#  'Moore',
#  'Nash',
#  'New Hanover',
#  'Northampton',
#  'Onslow',
#  'Orange',
#  'Out of NC',
#  'Pamlico',
#  'Pasquotank',
# ...

# %%
# import pygame
import pygame

# initialize game engine
pygame.init()

window_width=700
window_height=700

animation_increment=10
clock_tick_rate=20

# Open a window
size = (900, 700)
screen = pygame.display.set_mode(size)

# Set title to the window
pygame.display.set_caption("Covid USA")

dead=False

clock = pygame.time.Clock()
background_image = pygame.image.load("NC.jpg").convert()

while(dead==False):
    background_image= pygame.transform.smoothscale(background_image, (900,700))
    
    for event in pygame.event.get():

        if event.type == pygame.MOUSEBUTTONUP:
            start = event.pos
            print("start",start)

        if event.type == pygame.QUIT:
            dead = True
    screen.blit(background_image, [0, 0])
    printear()
    
    pygame.display.flip()
    pygame.display.update()
    clock.tick(clock_tick_rate)

# %%
pygame.quit()

# %%
def muertos_dia(d):
    x=list(dades2.columns)
    y=x.index(d)
    return dades2.iloc[:,[0,y]]
